# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'

import tensorflow as tf
import numpy as np

a = tf.constant(5, name="a")
b = tf.constant(6, name="b")
c = tf.add(a, b, name="add")

writer = tf.summary.FileWriter("graphs", tf.get_default_graph())
with tf.Session() as sess:
    print (sess.run(c))
writer.close()

a = tf.constant([5,4], name="a")
b = tf.constant([[1,2], [3,4]], name="b")
with tf.Session() as sess:
    print(sess.run(tf.div(b,a)))
    print(sess.run(tf.divide(b,a)))

a = tf.constant([5,4], name="a")
b = tf.constant([1,2], name="b")
with tf.Session() as sess:
    print(sess.run(tf.multiply(a,b)))
    print(sess.run(tf.tensordot(a,b,1)))

t_0 = 19
x = tf.zeros_like(t_0)
y = tf.ones_like(t_0)

t_1 = ["apple", "pie", "banana"]
x = tf.zeros_like(t_1)
#y = tf.ones_like(t_1)
 
t_2 = [[True, False, False],
       [False, False, True],
       [False, True, False]]
x = tf.zeros_like(t_2)
y = tf.ones_like(t_2)

print(tf.int32.as_numpy_dtype())

my_const = tf.constant([1.0,2.0], name="my_const")
print(tf.get_default_graph().as_graph_def())
# Out:
# 11
# [[0 0]
#  [0 1]]
# [[ 0.2  0.5]
#  [ 0.6  1. ]]
# [5 8]
# 13
# 0
# node {
#   name: "a"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 5
#       }
#     }
#   }
# }
# node {
#   name: "b"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 6
#       }
#     }
#   }
# }
# node {
#   name: "add"
#   op: "Add"
#   input: "a"
#   input: "b"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "a_1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "\005\000\000\000\004\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "b_1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "\001\000\000\000\002\000\000\000\003\000\000\000\004\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "div"
#   op: "FloorDiv"
#   input: "b_1"
#   input: "a_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "truediv/Cast"
#   op: "Cast"
#   input: "b_1"
#   attr {
#     key: "DstT"
#     value {
#       type: DT_DOUBLE
#     }
#   }
#   attr {
#     key: "SrcT"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "truediv/Cast_1"
#   op: "Cast"
#   input: "a_1"
#   attr {
#     key: "DstT"
#     value {
#       type: DT_DOUBLE
#     }
#   }
#   attr {
#     key: "SrcT"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "truediv"
#   op: "RealDiv"
#   input: "truediv/Cast"
#   input: "truediv/Cast_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_DOUBLE
#     }
#   }
# }
# node {
#   name: "a_2"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 5
#       }
#     }
#   }
# }
# node {
#   name: "b_2"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 6
#       }
#     }
#   }
# }
# node {
#   name: "add_1"
#   op: "Add"
#   input: "a_2"
#   input: "b_2"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "a_3"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "\005\000\000\000\004\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "b_3"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "\001\000\000\000\002\000\000\000\003\000\000\000\004\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "div_1"
#   op: "FloorDiv"
#   input: "b_3"
#   input: "a_3"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "truediv_1/Cast"
#   op: "Cast"
#   input: "b_3"
#   attr {
#     key: "DstT"
#     value {
#       type: DT_DOUBLE
#     }
#   }
#   attr {
#     key: "SrcT"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "truediv_1/Cast_1"
#   op: "Cast"
#   input: "a_3"
#   attr {
#     key: "DstT"
#     value {
#       type: DT_DOUBLE
#     }
#   }
#   attr {
#     key: "SrcT"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "truediv_1"
#   op: "RealDiv"
#   input: "truediv_1/Cast"
#   input: "truediv_1/Cast_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_DOUBLE
#     }
#   }
# }
# node {
#   name: "a_4"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "\005\000\000\000\004\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "b_4"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "\001\000\000\000\002\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "Mul"
#   op: "Mul"
#   input: "a_4"
#   input: "b_4"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "a_5"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 5
#       }
#     }
#   }
# }
# node {
#   name: "b_5"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 6
#       }
#     }
#   }
# }
# node {
#   name: "add_2"
#   op: "Add"
#   input: "a_5"
#   input: "b_5"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "a_6"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "\005\000\000\000\004\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "b_6"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "\001\000\000\000\002\000\000\000\003\000\000\000\004\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "div_2"
#   op: "FloorDiv"
#   input: "b_6"
#   input: "a_6"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "truediv_2/Cast"
#   op: "Cast"
#   input: "b_6"
#   attr {
#     key: "DstT"
#     value {
#       type: DT_DOUBLE
#     }
#   }
#   attr {
#     key: "SrcT"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "truediv_2/Cast_1"
#   op: "Cast"
#   input: "a_6"
#   attr {
#     key: "DstT"
#     value {
#       type: DT_DOUBLE
#     }
#   }
#   attr {
#     key: "SrcT"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "truediv_2"
#   op: "RealDiv"
#   input: "truediv_2/Cast"
#   input: "truediv_2/Cast_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_DOUBLE
#     }
#   }
# }
# node {
#   name: "a_7"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "\005\000\000\000\004\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "b_7"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "\001\000\000\000\002\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "Mul_1"
#   op: "Mul"
#   input: "a_7"
#   input: "b_7"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "a_8"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 5
#       }
#     }
#   }
# }
# node {
#   name: "b_8"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 6
#       }
#     }
#   }
# }
# node {
#   name: "add_3"
#   op: "Add"
#   input: "a_8"
#   input: "b_8"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "a_9"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "\005\000\000\000\004\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "b_9"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "\001\000\000\000\002\000\000\000\003\000\000\000\004\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "div_3"
#   op: "FloorDiv"
#   input: "b_9"
#   input: "a_9"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "truediv_3/Cast"
#   op: "Cast"
#   input: "b_9"
#   attr {
#     key: "DstT"
#     value {
#       type: DT_DOUBLE
#     }
#   }
#   attr {
#     key: "SrcT"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "truediv_3/Cast_1"
#   op: "Cast"
#   input: "a_9"
#   attr {
#     key: "DstT"
#     value {
#       type: DT_DOUBLE
#     }
#   }
#   attr {
#     key: "SrcT"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "truediv_3"
#   op: "RealDiv"
#   input: "truediv_3/Cast"
#   input: "truediv_3/Cast_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_DOUBLE
#     }
#   }
# }
# node {
#   name: "a_10"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "\005\000\000\000\004\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "b_10"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "\001\000\000\000\002\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "Mul_2"
#   op: "Mul"
#   input: "a_10"
#   input: "b_10"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "a_11"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 5
#       }
#     }
#   }
# }
# node {
#   name: "b_11"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 6
#       }
#     }
#   }
# }
# node {
#   name: "add_4"
#   op: "Add"
#   input: "a_11"
#   input: "b_11"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "a_12"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "\005\000\000\000\004\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "b_12"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "\001\000\000\000\002\000\000\000\003\000\000\000\004\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "div_4"
#   op: "FloorDiv"
#   input: "b_12"
#   input: "a_12"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "truediv_4/Cast"
#   op: "Cast"
#   input: "b_12"
#   attr {
#     key: "DstT"
#     value {
#       type: DT_DOUBLE
#     }
#   }
#   attr {
#     key: "SrcT"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "truediv_4/Cast_1"
#   op: "Cast"
#   input: "a_12"
#   attr {
#     key: "DstT"
#     value {
#       type: DT_DOUBLE
#     }
#   }
#   attr {
#     key: "SrcT"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "truediv_4"
#   op: "RealDiv"
#   input: "truediv_4/Cast"
#   input: "truediv_4/Cast_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_DOUBLE
#     }
#   }
# }
# node {
#   name: "a_13"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "\005\000\000\000\004\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "b_13"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "\001\000\000\000\002\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "Mul_3"
#   op: "Mul"
#   input: "a_13"
#   input: "b_13"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "a_14"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 5
#       }
#     }
#   }
# }
# node {
#   name: "b_14"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 6
#       }
#     }
#   }
# }
# node {
#   name: "add_5"
#   op: "Add"
#   input: "a_14"
#   input: "b_14"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "a_15"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "\005\000\000\000\004\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "b_15"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "\001\000\000\000\002\000\000\000\003\000\000\000\004\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "div_5"
#   op: "FloorDiv"
#   input: "b_15"
#   input: "a_15"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "truediv_5/Cast"
#   op: "Cast"
#   input: "b_15"
#   attr {
#     key: "DstT"
#     value {
#       type: DT_DOUBLE
#     }
#   }
#   attr {
#     key: "SrcT"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "truediv_5/Cast_1"
#   op: "Cast"
#   input: "a_15"
#   attr {
#     key: "DstT"
#     value {
#       type: DT_DOUBLE
#     }
#   }
#   attr {
#     key: "SrcT"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "truediv_5"
#   op: "RealDiv"
#   input: "truediv_5/Cast"
#   input: "truediv_5/Cast_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_DOUBLE
#     }
#   }
# }
# node {
#   name: "a_16"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "\005\000\000\000\004\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "b_16"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "\001\000\000\000\002\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "Mul_4"
#   op: "Mul"
#   input: "a_16"
#   input: "b_16"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot/range/start"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot/range/limit"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot/range/delta"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot/range"
#   op: "Range"
#   input: "Tensordot/range/start"
#   input: "Tensordot/range/limit"
#   input: "Tensordot/range/delta"
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot/range_1/start"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot/range_1/limit"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot/range_1/delta"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot/range_1"
#   op: "Range"
#   input: "Tensordot/range_1/start"
#   input: "Tensordot/range_1/limit"
#   input: "Tensordot/range_1/delta"
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot/Shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 2
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot/Rank"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot/GreaterEqual/y"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot/GreaterEqual"
#   op: "GreaterEqual"
#   input: "Tensordot/range"
#   input: "Tensordot/GreaterEqual/y"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot/Cast"
#   op: "Cast"
#   input: "Tensordot/GreaterEqual"
#   attr {
#     key: "DstT"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "SrcT"
#     value {
#       type: DT_BOOL
#     }
#   }
# }
# node {
#   name: "Tensordot/mul"
#   op: "Mul"
#   input: "Tensordot/Cast"
#   input: "Tensordot/range"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot/Less/y"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot/Less"
#   op: "Less"
#   input: "Tensordot/range"
#   input: "Tensordot/Less/y"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot/Cast_1"
#   op: "Cast"
#   input: "Tensordot/Less"
#   attr {
#     key: "DstT"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "SrcT"
#     value {
#       type: DT_BOOL
#     }
#   }
# }
# node {
#   name: "Tensordot/add"
#   op: "Add"
#   input: "Tensordot/range"
#   input: "Tensordot/Rank"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot/mul_1"
#   op: "Mul"
#   input: "Tensordot/Cast_1"
#   input: "Tensordot/add"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot/add_1"
#   op: "Add"
#   input: "Tensordot/mul"
#   input: "Tensordot/mul_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot/range_2/start"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot/range_2/delta"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot/range_2"
#   op: "Range"
#   input: "Tensordot/range_2/start"
#   input: "Tensordot/Rank"
#   input: "Tensordot/range_2/delta"
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot/ListDiff"
#   op: "ListDiff"
#   input: "Tensordot/range_2"
#   input: "Tensordot/add_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "out_idx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot/Gather"
#   op: "Gather"
#   input: "Tensordot/Shape"
#   input: "Tensordot/ListDiff"
#   attr {
#     key: "Tindices"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tparams"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "validate_indices"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "Tensordot/Gather_1"
#   op: "Gather"
#   input: "Tensordot/Shape"
#   input: "Tensordot/add_1"
#   attr {
#     key: "Tindices"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tparams"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "validate_indices"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "Tensordot/Const"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot/Prod"
#   op: "Prod"
#   input: "Tensordot/Gather"
#   input: "Tensordot/Const"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "Tensordot/Const_1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot/Prod_1"
#   op: "Prod"
#   input: "Tensordot/Gather_1"
#   input: "Tensordot/Const_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "Tensordot/concat/axis"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot/concat"
#   op: "ConcatV2"
#   input: "Tensordot/Gather_1"
#   input: "Tensordot/Gather"
#   input: "Tensordot/concat/axis"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot/concat_1/axis"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot/concat_1"
#   op: "ConcatV2"
#   input: "Tensordot/ListDiff"
#   input: "Tensordot/add_1"
#   input: "Tensordot/concat_1/axis"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot/stack"
#   op: "Pack"
#   input: "Tensordot/Prod"
#   input: "Tensordot/Prod_1"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "axis"
#     value {
#       i: 0
#     }
#   }
# }
# node {
#   name: "Tensordot/transpose"
#   op: "Transpose"
#   input: "a_16"
#   input: "Tensordot/concat_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tperm"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot/Reshape"
#   op: "Reshape"
#   input: "Tensordot/transpose"
#   input: "Tensordot/stack"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot/Shape_1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 2
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot/Rank_1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot/GreaterEqual_1/y"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot/GreaterEqual_1"
#   op: "GreaterEqual"
#   input: "Tensordot/range_1"
#   input: "Tensordot/GreaterEqual_1/y"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot/Cast_2"
#   op: "Cast"
#   input: "Tensordot/GreaterEqual_1"
#   attr {
#     key: "DstT"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "SrcT"
#     value {
#       type: DT_BOOL
#     }
#   }
# }
# node {
#   name: "Tensordot/mul_2"
#   op: "Mul"
#   input: "Tensordot/Cast_2"
#   input: "Tensordot/range_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot/Less_1/y"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot/Less_1"
#   op: "Less"
#   input: "Tensordot/range_1"
#   input: "Tensordot/Less_1/y"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot/Cast_3"
#   op: "Cast"
#   input: "Tensordot/Less_1"
#   attr {
#     key: "DstT"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "SrcT"
#     value {
#       type: DT_BOOL
#     }
#   }
# }
# node {
#   name: "Tensordot/add_2"
#   op: "Add"
#   input: "Tensordot/range_1"
#   input: "Tensordot/Rank_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot/mul_3"
#   op: "Mul"
#   input: "Tensordot/Cast_3"
#   input: "Tensordot/add_2"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot/add_3"
#   op: "Add"
#   input: "Tensordot/mul_2"
#   input: "Tensordot/mul_3"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot/range_3/start"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot/range_3/delta"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot/range_3"
#   op: "Range"
#   input: "Tensordot/range_3/start"
#   input: "Tensordot/Rank_1"
#   input: "Tensordot/range_3/delta"
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot/ListDiff_1"
#   op: "ListDiff"
#   input: "Tensordot/range_3"
#   input: "Tensordot/add_3"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "out_idx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot/Gather_2"
#   op: "Gather"
#   input: "Tensordot/Shape_1"
#   input: "Tensordot/ListDiff_1"
#   attr {
#     key: "Tindices"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tparams"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "validate_indices"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "Tensordot/Gather_3"
#   op: "Gather"
#   input: "Tensordot/Shape_1"
#   input: "Tensordot/add_3"
#   attr {
#     key: "Tindices"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tparams"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "validate_indices"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "Tensordot/Const_2"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot/Prod_2"
#   op: "Prod"
#   input: "Tensordot/Gather_2"
#   input: "Tensordot/Const_2"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "Tensordot/Const_3"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot/Prod_3"
#   op: "Prod"
#   input: "Tensordot/Gather_3"
#   input: "Tensordot/Const_3"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "Tensordot/concat_2/axis"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot/concat_2"
#   op: "ConcatV2"
#   input: "Tensordot/Gather_3"
#   input: "Tensordot/Gather_2"
#   input: "Tensordot/concat_2/axis"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot/concat_3/axis"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot/concat_3"
#   op: "ConcatV2"
#   input: "Tensordot/add_3"
#   input: "Tensordot/ListDiff_1"
#   input: "Tensordot/concat_3/axis"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot/stack_1"
#   op: "Pack"
#   input: "Tensordot/Prod_3"
#   input: "Tensordot/Prod_2"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "axis"
#     value {
#       i: 0
#     }
#   }
# }
# node {
#   name: "Tensordot/transpose_1"
#   op: "Transpose"
#   input: "b_16"
#   input: "Tensordot/concat_3"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tperm"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot/Reshape_1"
#   op: "Reshape"
#   input: "Tensordot/transpose_1"
#   input: "Tensordot/stack_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot/MatMul"
#   op: "MatMul"
#   input: "Tensordot/Reshape"
#   input: "Tensordot/Reshape_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "transpose_a"
#     value {
#       b: false
#     }
#   }
#   attr {
#     key: "transpose_b"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "Tensordot/concat_4/axis"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot/concat_4"
#   op: "ConcatV2"
#   input: "Tensordot/Gather"
#   input: "Tensordot/Gather_2"
#   input: "Tensordot/concat_4/axis"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot"
#   op: "Reshape"
#   input: "Tensordot/MatMul"
#   input: "Tensordot/concat_4"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "a_17"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 5
#       }
#     }
#   }
# }
# node {
#   name: "b_17"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 6
#       }
#     }
#   }
# }
# node {
#   name: "add_6"
#   op: "Add"
#   input: "a_17"
#   input: "b_17"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "a_18"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "\005\000\000\000\004\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "b_18"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "\001\000\000\000\002\000\000\000\003\000\000\000\004\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "div_6"
#   op: "FloorDiv"
#   input: "b_18"
#   input: "a_18"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "truediv_6/Cast"
#   op: "Cast"
#   input: "b_18"
#   attr {
#     key: "DstT"
#     value {
#       type: DT_DOUBLE
#     }
#   }
#   attr {
#     key: "SrcT"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "truediv_6/Cast_1"
#   op: "Cast"
#   input: "a_18"
#   attr {
#     key: "DstT"
#     value {
#       type: DT_DOUBLE
#     }
#   }
#   attr {
#     key: "SrcT"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "truediv_6"
#   op: "RealDiv"
#   input: "truediv_6/Cast"
#   input: "truediv_6/Cast_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_DOUBLE
#     }
#   }
# }
# node {
#   name: "a_19"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "\005\000\000\000\004\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "b_19"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "\001\000\000\000\002\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "Mul_5"
#   op: "Mul"
#   input: "a_19"
#   input: "b_19"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot_1/range/start"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot_1/range/limit"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot_1/range/delta"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot_1/range"
#   op: "Range"
#   input: "Tensordot_1/range/start"
#   input: "Tensordot_1/range/limit"
#   input: "Tensordot_1/range/delta"
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot_1/range_1/start"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot_1/range_1/limit"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot_1/range_1/delta"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot_1/range_1"
#   op: "Range"
#   input: "Tensordot_1/range_1/start"
#   input: "Tensordot_1/range_1/limit"
#   input: "Tensordot_1/range_1/delta"
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot_1/Shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 2
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot_1/Rank"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot_1/GreaterEqual/y"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot_1/GreaterEqual"
#   op: "GreaterEqual"
#   input: "Tensordot_1/range"
#   input: "Tensordot_1/GreaterEqual/y"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot_1/Cast"
#   op: "Cast"
#   input: "Tensordot_1/GreaterEqual"
#   attr {
#     key: "DstT"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "SrcT"
#     value {
#       type: DT_BOOL
#     }
#   }
# }
# node {
#   name: "Tensordot_1/mul"
#   op: "Mul"
#   input: "Tensordot_1/Cast"
#   input: "Tensordot_1/range"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot_1/Less/y"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot_1/Less"
#   op: "Less"
#   input: "Tensordot_1/range"
#   input: "Tensordot_1/Less/y"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot_1/Cast_1"
#   op: "Cast"
#   input: "Tensordot_1/Less"
#   attr {
#     key: "DstT"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "SrcT"
#     value {
#       type: DT_BOOL
#     }
#   }
# }
# node {
#   name: "Tensordot_1/add"
#   op: "Add"
#   input: "Tensordot_1/range"
#   input: "Tensordot_1/Rank"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot_1/mul_1"
#   op: "Mul"
#   input: "Tensordot_1/Cast_1"
#   input: "Tensordot_1/add"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot_1/add_1"
#   op: "Add"
#   input: "Tensordot_1/mul"
#   input: "Tensordot_1/mul_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot_1/range_2/start"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot_1/range_2/delta"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot_1/range_2"
#   op: "Range"
#   input: "Tensordot_1/range_2/start"
#   input: "Tensordot_1/Rank"
#   input: "Tensordot_1/range_2/delta"
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot_1/ListDiff"
#   op: "ListDiff"
#   input: "Tensordot_1/range_2"
#   input: "Tensordot_1/add_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "out_idx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot_1/Gather"
#   op: "Gather"
#   input: "Tensordot_1/Shape"
#   input: "Tensordot_1/ListDiff"
#   attr {
#     key: "Tindices"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tparams"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "validate_indices"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "Tensordot_1/Gather_1"
#   op: "Gather"
#   input: "Tensordot_1/Shape"
#   input: "Tensordot_1/add_1"
#   attr {
#     key: "Tindices"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tparams"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "validate_indices"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "Tensordot_1/Const"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot_1/Prod"
#   op: "Prod"
#   input: "Tensordot_1/Gather"
#   input: "Tensordot_1/Const"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "Tensordot_1/Const_1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot_1/Prod_1"
#   op: "Prod"
#   input: "Tensordot_1/Gather_1"
#   input: "Tensordot_1/Const_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "Tensordot_1/concat/axis"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot_1/concat"
#   op: "ConcatV2"
#   input: "Tensordot_1/Gather_1"
#   input: "Tensordot_1/Gather"
#   input: "Tensordot_1/concat/axis"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot_1/concat_1/axis"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot_1/concat_1"
#   op: "ConcatV2"
#   input: "Tensordot_1/ListDiff"
#   input: "Tensordot_1/add_1"
#   input: "Tensordot_1/concat_1/axis"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot_1/stack"
#   op: "Pack"
#   input: "Tensordot_1/Prod"
#   input: "Tensordot_1/Prod_1"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "axis"
#     value {
#       i: 0
#     }
#   }
# }
# node {
#   name: "Tensordot_1/transpose"
#   op: "Transpose"
#   input: "a_19"
#   input: "Tensordot_1/concat_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tperm"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot_1/Reshape"
#   op: "Reshape"
#   input: "Tensordot_1/transpose"
#   input: "Tensordot_1/stack"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot_1/Shape_1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 2
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot_1/Rank_1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
# ...
#   }
# }
# node {
#   name: "Tensordot_4/Prod_1"
#   op: "Prod"
#   input: "Tensordot_4/Gather_1"
#   input: "Tensordot_4/Const_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "Tensordot_4/concat/axis"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot_4/concat"
#   op: "ConcatV2"
#   input: "Tensordot_4/Gather_1"
#   input: "Tensordot_4/Gather"
#   input: "Tensordot_4/concat/axis"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot_4/concat_1/axis"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot_4/concat_1"
#   op: "ConcatV2"
#   input: "Tensordot_4/ListDiff"
#   input: "Tensordot_4/add_1"
#   input: "Tensordot_4/concat_1/axis"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot_4/stack"
#   op: "Pack"
#   input: "Tensordot_4/Prod"
#   input: "Tensordot_4/Prod_1"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "axis"
#     value {
#       i: 0
#     }
#   }
# }
# node {
#   name: "Tensordot_4/transpose"
#   op: "Transpose"
#   input: "a_28"
#   input: "Tensordot_4/concat_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tperm"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot_4/Reshape"
#   op: "Reshape"
#   input: "Tensordot_4/transpose"
#   input: "Tensordot_4/stack"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot_4/Shape_1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 2
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot_4/Rank_1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot_4/GreaterEqual_1/y"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot_4/GreaterEqual_1"
#   op: "GreaterEqual"
#   input: "Tensordot_4/range_1"
#   input: "Tensordot_4/GreaterEqual_1/y"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot_4/Cast_2"
#   op: "Cast"
#   input: "Tensordot_4/GreaterEqual_1"
#   attr {
#     key: "DstT"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "SrcT"
#     value {
#       type: DT_BOOL
#     }
#   }
# }
# node {
#   name: "Tensordot_4/mul_2"
#   op: "Mul"
#   input: "Tensordot_4/Cast_2"
#   input: "Tensordot_4/range_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot_4/Less_1/y"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot_4/Less_1"
#   op: "Less"
#   input: "Tensordot_4/range_1"
#   input: "Tensordot_4/Less_1/y"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot_4/Cast_3"
#   op: "Cast"
#   input: "Tensordot_4/Less_1"
#   attr {
#     key: "DstT"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "SrcT"
#     value {
#       type: DT_BOOL
#     }
#   }
# }
# node {
#   name: "Tensordot_4/add_2"
#   op: "Add"
#   input: "Tensordot_4/range_1"
#   input: "Tensordot_4/Rank_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot_4/mul_3"
#   op: "Mul"
#   input: "Tensordot_4/Cast_3"
#   input: "Tensordot_4/add_2"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot_4/add_3"
#   op: "Add"
#   input: "Tensordot_4/mul_2"
#   input: "Tensordot_4/mul_3"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot_4/range_3/start"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot_4/range_3/delta"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot_4/range_3"
#   op: "Range"
#   input: "Tensordot_4/range_3/start"
#   input: "Tensordot_4/Rank_1"
#   input: "Tensordot_4/range_3/delta"
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot_4/ListDiff_1"
#   op: "ListDiff"
#   input: "Tensordot_4/range_3"
#   input: "Tensordot_4/add_3"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "out_idx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot_4/Gather_2"
#   op: "Gather"
#   input: "Tensordot_4/Shape_1"
#   input: "Tensordot_4/ListDiff_1"
#   attr {
#     key: "Tindices"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tparams"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "validate_indices"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "Tensordot_4/Gather_3"
#   op: "Gather"
#   input: "Tensordot_4/Shape_1"
#   input: "Tensordot_4/add_3"
#   attr {
#     key: "Tindices"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tparams"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "validate_indices"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "Tensordot_4/Const_2"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot_4/Prod_2"
#   op: "Prod"
#   input: "Tensordot_4/Gather_2"
#   input: "Tensordot_4/Const_2"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "Tensordot_4/Const_3"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot_4/Prod_3"
#   op: "Prod"
#   input: "Tensordot_4/Gather_3"
#   input: "Tensordot_4/Const_3"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "Tensordot_4/concat_2/axis"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot_4/concat_2"
#   op: "ConcatV2"
#   input: "Tensordot_4/Gather_3"
#   input: "Tensordot_4/Gather_2"
#   input: "Tensordot_4/concat_2/axis"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot_4/concat_3/axis"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot_4/concat_3"
#   op: "ConcatV2"
#   input: "Tensordot_4/add_3"
#   input: "Tensordot_4/ListDiff_1"
#   input: "Tensordot_4/concat_3/axis"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot_4/stack_1"
#   op: "Pack"
#   input: "Tensordot_4/Prod_3"
#   input: "Tensordot_4/Prod_2"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "axis"
#     value {
#       i: 0
#     }
#   }
# }
# node {
#   name: "Tensordot_4/transpose_1"
#   op: "Transpose"
#   input: "b_28"
#   input: "Tensordot_4/concat_3"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tperm"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot_4/Reshape_1"
#   op: "Reshape"
#   input: "Tensordot_4/transpose_1"
#   input: "Tensordot_4/stack_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot_4/MatMul"
#   op: "MatMul"
#   input: "Tensordot_4/Reshape"
#   input: "Tensordot_4/Reshape_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "transpose_a"
#     value {
#       b: false
#     }
#   }
#   attr {
#     key: "transpose_b"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "Tensordot_4/concat_4/axis"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "Tensordot_4/concat_4"
#   op: "ConcatV2"
#   input: "Tensordot_4/Gather"
#   input: "Tensordot_4/Gather_2"
#   input: "Tensordot_4/concat_4/axis"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Tensordot_4"
#   op: "Reshape"
#   input: "Tensordot_4/MatMul"
#   input: "Tensordot_4/concat_4"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "zeros_like_9/tensor"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 19
#       }
#     }
#   }
# }
# node {
#   name: "zeros_like_9"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "ones_like_6/tensor"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 19
#       }
#     }
#   }
# }
# node {
#   name: "ones_like_6/Shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "ones_like_6/Const"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "ones_like_6"
#   op: "Fill"
#   input: "ones_like_6/Shape"
#   input: "ones_like_6/Const"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "zeros_like_10/tensor"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_STRING
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_STRING
#         tensor_shape {
#           dim {
#             size: 3
#           }
#         }
#         string_val: "apple"
#         string_val: "pie"
#         string_val: "banana"
#       }
#     }
#   }
# }
# node {
#   name: "zeros_like_10"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_STRING
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_STRING
#         tensor_shape {
#           dim {
#             size: 3
#           }
#         }
#         string_val: ""
#       }
#     }
#   }
# }
# node {
#   name: "zeros_like_11/tensor"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_BOOL
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_BOOL
#         tensor_shape {
#           dim {
#             size: 3
#           }
#           dim {
#             size: 3
#           }
#         }
#         bool_val: true
#         bool_val: false
#         bool_val: false
#         bool_val: false
#         bool_val: false
#         bool_val: true
#         bool_val: false
#         bool_val: true
#         bool_val: false
#       }
#     }
#   }
# }
# node {
#   name: "zeros_like_11"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_BOOL
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_BOOL
#         tensor_shape {
#           dim {
#             size: 3
#           }
#           dim {
#             size: 3
#           }
#         }
#         bool_val: false
#       }
#     }
#   }
# }
# node {
#   name: "ones_like_7/tensor"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_BOOL
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_BOOL
#         tensor_shape {
#           dim {
#             size: 3
#           }
#           dim {
#             size: 3
#           }
#         }
#         bool_val: true
#         bool_val: false
#         bool_val: false
#         bool_val: false
#         bool_val: false
#         bool_val: true
#         bool_val: false
#         bool_val: true
#         bool_val: false
#       }
#     }
#   }
# }
# node {
#   name: "ones_like_7/Shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "\003\000\000\000\003\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "ones_like_7/Const"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_BOOL
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_BOOL
#         tensor_shape {
#         }
#         bool_val: true
#       }
#     }
#   }
# }
# node {
#   name: "ones_like_7"
#   op: "Fill"
#   input: "ones_like_7/Shape"
#   input: "ones_like_7/Const"
#   attr {
#     key: "T"
#     value {
#       type: DT_BOOL
#     }
#   }
# }
# node {
#   name: "my_const"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "\000\000\200?\000\000\000@"
#       }
#     }
#   }
# }
# versions {
#   producer: 22
# }
